# %%
import os
import pandas as pd
import numpy as np
import json

# %%
usagedf = pd.read_csv("Pokemon Usage/SeptemberData.csv",index_col=0)
usagedf.head()
# Out:
#       index                                              Moves     Usage  Gen  \
# 0  Bronzong  ['gyroball', 'explosion', 'earthquake', 'steal...  0.124514    4
# 1  Swampert  ['earthquake', 'stealthrock', 'waterfall', 'ic...  0.120051    4
# 2   Snorlax  ['bodyslam', 'crunch', 'earthquake', 'curse', ...  0.040116    4
# 3      Uxie  ['stealthrock', 'uturn', 'thunderwave', 'psych...  0.023561    4
# 4   Machamp  ['dynamicpunch', 'payback', 'bulletpunch', 'ic...  0.102777    4
#
#   Format  Min Rating  Recent
# 0     ou         0.0       1
# 1     ou         0.0       1
# 2     ou         0.0       1
# 3     ou         0.0       1
# 4     ou         0.0       1

# %%
movesdf = pd.read_csv("Pokedex and Moves/moves.csv", index_col=0).set_index('move')
movesdf.head()
# Out:
#                                                 name      type
# move
# 10000000voltthunderbolt  10,000,000 Volt Thunderbolt  Electric
# absorb                                        Absorb     Grass
# accelerock                                Accelerock      Rock
# acid                                            Acid    Poison
# acidarmor                                 Acid Armor    Poison

# %%
def standardize_moves(df):
    type1 = []
    type2 = []
    type3 = []
    type4 = []
    type5 = []
    type6 = []
    type_list = [type1, type2, type3, type4, type5, type6]

    for row in range(len(df["Moves"])):
        moves = df["Moves"][row].strip('][').split(', ')
        list_num = 0
        for each in range(6):
            if each >= len(moves):
                move_type = np.nan
                type_list[list_num].append(move_type)
                list_num += 1

            else:
                string = moves[each].replace("'","")
                if (string) == "":
                    move_type = np.nan
                    type_list[list_num].append(move_type)
                    list_num += 1
                else:
                    move_type = movesdf.loc[string]['type']
                    type_list[list_num].append(move_type)
                    list_num += 1
    df["Type 1"] = type_list[0]
    df["Type 2"] = type_list[1]
    df["Type 3"] = type_list[2]
    df["Type 4"] = type_list[3]
    df["Type 5"] = type_list[4]
    df["Type 6"] = type_list[5]

    return df

# %%
check = standardize_moves(usagedf)

# %%
check[["Type 1", "Type 2", "Type 3","Type 4","Type 5","Type 6"]]["Type 1"].value_counts()
# Out:
# Normal      395
# Ground      283
# Flying      164
# Fighting    161
# Dark        161
# Water       154
# Steel       153
# Grass       134
# Electric    131
# Dragon      130
# Ice         121
# Fairy       116
# Rock        110
# Fire        107
# Bug         103
# Ghost       103
# Psychic      96
# Poison       68
# Name: Type 1, dtype: int64

# %%
check
# Out:
#           index                                              Moves     Usage  \
# 0      Bronzong  ['gyroball', 'explosion', 'earthquake', 'steal...  0.124514
# 1      Swampert  ['earthquake', 'stealthrock', 'waterfall', 'ic...  0.120051
# 2       Snorlax  ['bodyslam', 'crunch', 'earthquake', 'curse', ...  0.040116
# 3          Uxie  ['stealthrock', 'uturn', 'thunderwave', 'psych...  0.023561
# 4       Machamp  ['dynamicpunch', 'payback', 'bulletpunch', 'ic...  0.102777
# ...         ...                                                ...       ...
# 2697     Zarude  ['darkestlariat', 'powerwhip', 'uturn', 'jungl...  0.126021
# 2698  Azumarill  ['aquajet', 'playrough', 'knockoff', 'liquidat...  0.064454
# 2699    Jirachi  ['uturn', 'ironhead', 'trick', 'stealthrock', ...  0.236278
# 2700      Azelf  ['fireblast', 'knockoff', 'psychic', 'uturn', ...  0.093916
# 2701    Kingdra  ['dracometeor', 'hurricane', 'surf', 'flipturn...  0.022433
#
#       Gen Format  Min Rating  Recent    Type 1  Type 2    Type 3   Type 4  \
# 0       4     ou         0.0       1     Steel  Normal    Ground     Rock
# 1       4     ou         0.0       1    Ground    Rock     Water      Ice
# 2       4     ou         0.0       1    Normal    Dark    Ground    Ghost
# 3       4     ou         0.0       1      Rock     Bug  Electric  Psychic
# 4       4     ou         0.0       1  Fighting    Dark     Steel      Ice
# ...   ...    ...         ...     ...       ...     ...       ...      ...
# 2697    8     uu      1760.0       1      Dark   Grass       Bug    Grass
# 2698    8     uu      1760.0       1     Water   Fairy      Dark    Water
# 2699    8     uu      1760.0       1       Bug   Steel   Psychic     Rock
# 2700    8     uu      1760.0       1      Fire    Dark   Psychic      Bug
# 2701    8     uu      1760.0       1    Dragon  Flying     Water    Water
#
#         Type 5   Type 6
# 0      Psychic    Water
# 1          Ice   Normal
# 2      Psychic     Fire
# 3      Psychic  Psychic
# 4         Rock   Normal
# ...        ...      ...
# 2697  Fighting   Flying
# 2698    Normal      Ice
# 2699   Psychic   Normal
# 2700   Psychic     Dark
# 2701     Water      Ice
#
# [2702 rows x 13 columns]
