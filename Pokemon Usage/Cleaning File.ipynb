# %%
import clean
import os

# %%
# Change to Path to Folder holding raw data, add the "/" at the end
path_to_dir = "September/raw/gen4/"

for filename in os.listdir(path_to_dir):

    #Change first part to Path to Folder holding Clean Data, add the "/"
    output = "September/data/gen4/" + str(filename[:-5])
    path_to_file = path_to_dir + str(filename)
    df = clean.clean_df(path_to_file)
    df.to_csv(output)

# %%
import pandas as pd 
pd.read_csv("September/data/gen8/gen8ubers-0", index_col = 0)
# Out:
#                                                               Moves     Usage  \
# Calyrex-Ice       ['glaciallance', 'highhorsepower', 'trickroom'...  0.053496
# Lunala            ['moongeistbeam', 'roost', 'moonblast', 'icebe...  0.021551
# Landorus-Therian  ['earthquake', 'uturn', 'stealthrock', 'knocko...  0.035229
# Blissey           ['softboiled', 'seismictoss', 'toxic', 'aromat...  0.043927
# Marshadow         ['spectralthief', 'shadowsneak', 'closecombat'...  0.203578
# ...                                                             ...       ...
# Giratina-Origin   ['shadowsneak', 'poltergeist', 'dracometeor', ...  0.032603
# Ho-Oh             ['sacredfire', 'defog', 'bravebird', 'toxic', ...  0.120720
# Tyranitar         ['crunch', 'earthquake', 'stoneedge', 'stealth...  0.035511
# Kyogre            ['icebeam', 'thunder', 'waterspout', 'originpu...  0.194387
# Dracovish         ['fishiousrend', 'crunch', 'psychicfangs', 'ou...  0.125380
#
#                   Gen Format  Min Rating
# Calyrex-Ice         8  ubers           0
# Lunala              8  ubers           0
# Landorus-Therian    8  ubers           0
# Blissey             8  ubers           0
# Marshadow           8  ubers           0
# ...               ...    ...         ...
# Giratina-Origin     8  ubers           0
# Ho-Oh               8  ubers           0
# Tyranitar           8  ubers           0
# Kyogre              8  ubers           0
# Dracovish           8  ubers           0
#
# [61 rows x 5 columns]
