# %%
import clean
import os

# %%
# Change to Path to Folder holding raw data, add the "/" at the end
path_to_dir = "Oldest Data/raw/gen6/"

for filename in os.listdir(path_to_dir):

    #Change first part to Path to Folder holding Clean Data, add the "/"
    output = "Oldest Data/data/gen6/" + str(filename[:-5])
    print(filename)
    path_to_file = path_to_dir + str(filename)
    df = clean.old_clean(path_to_file)
    df.to_csv(output)
# Out:
# ou-0.json
# ou-1500.json
# ou-1695.json
# ou-1825.json
# ubers-0.json
# ubers-1500.json
# ubers-1630.json
# ubers-1760.json
# uu-0.json
# uu-1500.json
# uu-1630.json
# uu-1760.json

# %%
import pandas as pd

# %%
# Observation Count
path_to_dir = "September/data/"
obs = 0
obs_prev = 0

for filename in os.listdir(path_to_dir):
    inner = path_to_dir + str(filename) + "/"
    for inner_file in os.listdir(inner):
        df_file = inner + str(inner_file)
        df = pd.read_csv(df_file,index_col=0)
        obs += df.shape[0]
    print(inner,obs - obs_prev)
    obs_prev = obs

obs
# Out:
# September/data/gen4/ 485
# September/data/gen5/ 205
# September/data/gen6/ 274
# September/data/gen7/ 501
# September/data/gen8/ 1237
# 2702

# %%
path_to_dir = "September/data/"
obs = 0
df = None

for filename in os.listdir(path_to_dir):
    inner = path_to_dir + str(filename) + "/"
    for inner_file in os.listdir(inner):
        df_file = inner + str(inner_file)
        if df is None:
            df = pd.read_csv(df_file, index_col=0).reset_index()
        else:
            temp_df = pd.read_csv(df_file, index_col=0).reset_index()
            df = df.merge(temp_df, how = "outer")

df
# Out:
#           index                                              Moves     Usage  \
# 0      Bronzong  ['gyroball', 'explosion', 'earthquake', 'steal...  0.124514
# 1      Swampert  ['earthquake', 'stealthrock', 'waterfall', 'ic...  0.120051
# 2       Snorlax  ['bodyslam', 'crunch', 'earthquake', 'curse', ...  0.040116
# 3          Uxie  ['stealthrock', 'uturn', 'thunderwave', 'psych...  0.023561
# 4       Machamp  ['dynamicpunch', 'payback', 'bulletpunch', 'ic...  0.102777
# ...         ...                                                ...       ...
# 2697     Zarude  ['darkestlariat', 'powerwhip', 'uturn', 'jungl...  0.126021
# 2698  Azumarill  ['aquajet', 'playrough', 'knockoff', 'liquidat...  0.064454
# 2699    Jirachi  ['uturn', 'ironhead', 'trick', 'stealthrock', ...  0.236278
# 2700      Azelf  ['fireblast', 'knockoff', 'psychic', 'uturn', ...  0.093916
# 2701    Kingdra  ['dracometeor', 'hurricane', 'surf', 'flipturn...  0.022433
#
#       Gen Format  Min Rating
# 0       4     ou         0.0
# 1       4     ou         0.0
# 2       4     ou         0.0
# 3       4     ou         0.0
# 4       4     ou         0.0
# ...   ...    ...         ...
# 2697    8     uu      1760.0
# 2698    8     uu      1760.0
# 2699    8     uu      1760.0
# 2700    8     uu      1760.0
# 2701    8     uu      1760.0
#
# [2702 rows x 6 columns]

# %%
df["Gen"].value_counts()
# Out:
# 8    1237
# 7     501
# 4     485
# 6     274
# 5     205
# Name: Gen, dtype: int64

# %%
path_to_dir = "Oldest Data/data/"
obs = 0
obs_prev = 0

for filename in os.listdir(path_to_dir):
    inner = path_to_dir + str(filename) + "/"

    for inner_file in os.listdir(inner):
        df_file = inner + str(inner_file)
        df = pd.read_csv(df_file,index_col=0)
        obs += df.shape[0]
    print(inner,obs - obs_prev)
    obs_prev = obs
obs
# Out:
# Oldest Data/data/gen4/ 317
# Oldest Data/data/gen5/ 590
# Oldest Data/data/gen6/ 1532
# Oldest Data/data/gen7/ 468
# Oldest Data/data/gen8/ 392
# 3299

# %%
path_to_dir = "Oldest Data/data/"
obs = 0
df = None

for filename in os.listdir(path_to_dir):
    inner = path_to_dir + str(filename) + "/"
    for inner_file in os.listdir(inner):
        df_file = inner + str(inner_file)
        if df is None:
            df = pd.read_csv(df_file, index_col=0).reset_index()
        else:
            temp_df = pd.read_csv(df_file, index_col=0).reset_index()
            print(df_file, temp_df.shape[0])
            df = df.merge(temp_df, how = "outer")
df
# Out:
# Oldest Data/data/gen4/gen4ou-1500 74
# Oldest Data/data/gen4/gen4ou-1630 66
# Oldest Data/data/gen4/gen4ou-1760 61
# Oldest Data/data/gen4/gen4ubers-0 21
# Oldest Data/data/gen4/gen4ubers-1500 21
# Oldest Data/data/gen5/gen5ou-0 104
# Oldest Data/data/gen5/gen5ou-1500 104
# Oldest Data/data/gen5/gen5ou-1630 98
# Oldest Data/data/gen5/gen5ou-1760 90
# Oldest Data/data/gen5/gen5ubers-0 66
# Oldest Data/data/gen5/gen5ubers-1500 66
# Oldest Data/data/gen5/gen5uu-0 31
# Oldest Data/data/gen5/gen5uu-1500 31
# Oldest Data/data/gen6/ou-0 140
# Oldest Data/data/gen6/ou-1500 140
# Oldest Data/data/gen6/ou-1695 140
# Oldest Data/data/gen6/ou-1825 140
# Oldest Data/data/gen6/ubers-0 123
# Oldest Data/data/gen6/ubers-1500 123
# Oldest Data/data/gen6/ubers-1630 123
# Oldest Data/data/gen6/ubers-1760 123
# Oldest Data/data/gen6/uu-0 120
# Oldest Data/data/gen6/uu-1500 120
# Oldest Data/data/gen6/uu-1630 120
# Oldest Data/data/gen6/uu-1760 120
# Oldest Data/data/gen7/gen7ou-0 67
# Oldest Data/data/gen7/gen7ou-1500 68
# Oldest Data/data/gen7/gen7ou-1695 62
# Oldest Data/data/gen7/gen7ou-1825 58
# Oldest Data/data/gen7/gen7ubers-0 62
# Oldest Data/data/gen7/gen7ubers-1500 60
# Oldest Data/data/gen7/gen7ubers-1630 49
# Oldest Data/data/gen7/gen7ubers-1760 42
# Oldest Data/data/gen8/gen8ou-0 67
# Oldest Data/data/gen8/gen8ou-1500 63
# Oldest Data/data/gen8/gen8ou-1695 47
# Oldest Data/data/gen8/gen8ou-1825 42
# Oldest Data/data/gen8/gen8ubers-0 49
# Oldest Data/data/gen8/gen8ubers-1500 48
# Oldest Data/data/gen8/gen8ubers-1630 40
# Oldest Data/data/gen8/gen8ubers-1760 36
#                index                                              Moves  \
# 0          Porygon-Z  ['triattack', 'darkpulse', 'icebeam', 'thunder...
# 1           Bronzong  ['explosion', 'stealthrock', 'gyroball', 'refl...
# 2           Swampert  ['earthquake', 'stealthrock', 'roar', 'icebeam...
# 3          Spiritomb  ['rest', 'willowisp', 'pursuit', 'sleeptalk', ...
# 4            Snorlax  ['rest', 'bodyslam', 'curse', 'crunch', 'earth...
# ...              ...                                                ...
# 2706       Charizard  ['solarbeam', 'fireblast', 'hurricane', 'airsl...
# 2707         Shuckle  ['stickyweb', 'stealthrock', 'encore', 'finalg...
# 2708       Hatterene  ['mysticalfire', 'psychic', 'dazzlinggleam', '...
# 2709  Zacian-Crowned  ['behemothblade', 'playrough', 'swordsdance', ...
# 2710       Hydreigon  ['dracometeor', 'nastyplot', 'flamethrower', '...
#
#          Usage  Gen Format  Min Rating
# 0     0.030726    4     ou           0
# 1     0.062849    4     ou           0
# 2     0.321229    4     ou           0
# 3     0.064246    4     ou           0
# 4     0.087989    4     ou           0
# ...        ...  ...    ...         ...
# 2706  0.030482    8  ubers           0
# 2707  0.045773    8  ubers           0
# 2708  0.026064    8  ubers           0
# 2709  0.921806    8  ubers           0
# 2710  0.033010    8  ubers           0
#
# [2711 rows x 6 columns]

# %%
df["Gen"].value_counts()
# Out:
# 6    1203
# 7     468
# 5     423
# 8     392
# 4     225
# Name: Gen, dtype: int64

# %%
path_to_dir = "September/data/gen6/ubers-1500"

# %%
raw = pd.read_csv(path_to_dir)
raw
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-06f7eebe034d> in <module>
# ----> 1 raw = pd.read_csv(path_to_dir)
#       2 raw
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'September/data/gen6/ubers-1500'

# %%
path_to_dir = "September/data/gen6/gen6ou-1630"

# %%
df = pd.read_csv(path_to_dir)
df
# Out:
#         Unnamed: 0                                              Moves  \
# 0        Volcarona  ['quiverdance', 'bugbuzz', 'gigadrain', 'fireb...
# 1   Manectric-Mega  ['voltswitch', 'hiddenpowerice', 'thunderbolt'...
# 2          Gliscor  ['earthquake', 'roost', 'swordsdance', 'facade...
# 3     Altaria-Mega  ['dragondance', 'roost', 'healbell', 'frustrat...
# 4    Alakazam-Mega  ['focusblast', 'psychic', 'shadowball', 'calmm...
# ..             ...                                                ...
# 60         Jirachi  ['ironhead', 'uturn', 'healingwish', 'stealthr...
# 61       Hydreigon  ['darkpulse', 'dracometeor', 'flashcannon', 'f...
# 62           Azelf  ['stealthrock', 'taunt', 'explosion', 'firebla...
# 63        Skarmory  ['roost', 'whirlwind', 'spikes', 'bravebird', ...
# 64         Kingdra  ['dracometeor', 'icebeam', 'hydropump', 'scald...
#
#        Usage  Gen Format  Min Rating
# 0   0.051096    6     ou      1630.0
# 1   0.037005    6     ou      1630.0
# 2   0.085261    6     ou      1630.0
# 3   0.020650    6     ou      1630.0
# 4   0.038036    6     ou      1630.0
# ..       ...  ...    ...         ...
# 60  0.046705    6     ou      1630.0
# 61  0.033398    6     ou      1630.0
# 62  0.035384    6     ou      1630.0
# 63  0.096409    6     ou      1630.0
# 64  0.021266    6     ou      1630.0
#
# [65 rows x 6 columns]
